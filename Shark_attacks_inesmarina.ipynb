# %%
import pandas as pd
import numpy as np

# %%
pip install chardet
# Out:
# Collecting chardet
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Installing collected packages: chardet
# Successfully installed chardet-5.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import chardet

# Lee los primeros 10000 bytes para detectar el encoding
with open('attacks.csv', 'rb') as f:
    result = chardet.detect(f.read(10000))

# Muestra el encoding detectado
print(result['encoding'])

# Usa el encoding detectado para leer el archivo
df = pd.read_csv('attacks.csv', encoding=result['encoding'])
# Out:
# Windows-1252

# %%
df.head(10)
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7    2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# 0                        Oceanside, San Diego County      Paddling
# 1                     St. Simon Island, Glynn County      Standing
# 2                                       Habush, Oahu       Surfing
# 3                                 Arrawarra Headland       Surfing
# 4                                           La Ticla   Free diving
# 5                                 Flat Rock, Ballina  Kite surfing
# 6                              Piedade Beach, Recife      Swimming
# 7  Lighhouse Point Park, Ponce Inlet, Volusia County       Fishing
# 8                       Cocoa Beach, Brevard  County       Walking
# 9                      Daytona Beach, Volusia County      Standing
#
#                      Name Sex   ...         Species   \
# 0             Julie Wolfe    F  ...      White shark
# 1         Adyson McNeely     F  ...              NaN
# 2             John Denges    M  ...              NaN
# 3                    male    M  ...        2 m shark
# 4          Gustavo Ramos     M  ...  Tiger shark, 3m
# 5                 Chris …    M  ...              NaN
# 6  Jose Ernesto da Silva     M  ...      Tiger shark
# 7                    male    M  ...  Lemon shark, 3'
# 8               Cody High    M  ...   Bull shark, 6'
# 9                    male    M  ...              NaN
#
#              Investigator or Source                            pdf  \
# 0                  R. Collier, GSAF           2018.06.25-Wolfe.pdf
# 1    K.McMurray, TrackingSharks.com         2018.06.18-McNeely.pdf
# 2    K.McMurray, TrackingSharks.com          2018.06.09-Denges.pdf
# 3                    B. Myatt, GSAF       2018.06.08-Arrawarra.pdf
# 4                         A .Kipper           2018.06.04-Ramos.pdf
# 5         Daily Telegraph, 6/4/2018      2018.06.03.b-FlatRock.pdf
# 6    Diario de Pernambuco, 6/4/2018       2018.06.03.a-daSilva.pdf
# 7   K. McMurray, TrackingSharks.com           2018.05.27-Ponce.pdf
# 8    K.McMurray, TrackingSharks.com          2018.05.26.b-High.pdf
# 9  K. McMurray, Tracking Sharks.com  2018.05.26.a-DaytonaBeach.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.b
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.a
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.27
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.26.b
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.26.a
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
# 5  2018.06.03.b         6298.0         NaN         NaN
# 6  2018.06.03.a         6297.0         NaN         NaN
# 7    2018.05.27         6296.0         NaN         NaN
# 8  2018.05.26.b         6295.0         NaN         NaN
# 9  2018.05.26.a         6294.0         NaN         NaN
#
# [10 rows x 24 columns]

# %%
df.sample(10)
# Out:
#         Case Number                  Date    Year        Type  \
# 1270   2008.04.20.a           20-Apr-2008  2008.0  Unprovoked
# 20564           NaN                   NaN     NaN         NaN
# 8160              0                   NaN     NaN         NaN
# 3477   1968.04.11.R  Reported 11-Apr-1968  1968.0  Unprovoked
# 22426           NaN                   NaN     NaN         NaN
# 4566   1947.11.08.a           08-Nov-1947  1947.0  Unprovoked
# 4130     1958.12.13           13-Dec-1958  1958.0  Unprovoked
# 18339           NaN                   NaN     NaN         NaN
# 18609           NaN                   NaN     NaN         NaN
# 6171     1555.00.00                  1555  1555.0  Unprovoked
#
#                 Country             Area  \
# 1270          AUSTRALIA  New South Wales
# 20564               NaN              NaN
# 8160                NaN              NaN
# 3477   PAPUA NEW GUINEA    Gulf Province
# 22426               NaN              NaN
# 4566          AUSTRALIA  New South Wales
# 4130                USA           Hawaii
# 18339               NaN              NaN
# 18609               NaN              NaN
# 6171                NaN              NaN
#
#                                                 Location  \
# 1270                                       Crescent Head
# 20564                                                NaN
# 8160                                                 NaN
# 3477                                         Orokolo Bay
# 22426                                                NaN
# 4566   Maria River, Port Macquarie, 12 miles from riv...
# 4130   Near Twin Islands off Lanikai, O'ahu (east coast)
# 18339                                                NaN
# 18609                                                NaN
# 6171                                                 NaN
#
#                       Activity               Name Sex   ...  \
# 1270                       NaN    Jamie Adlington    M  ...
# 20564                      NaN                NaN  NaN  ...
# 8160                       NaN                NaN  NaN  ...
# 3477                  Swimming  Hukolapa Laiokeke    M  ...
# 22426                      NaN                NaN  NaN  ...
# 4566                  Swimming      Rupert Elford    M  ...
# 4130   Surfing on air mattress  William S. Weaver    M  ...
# 18339                      NaN                NaN  NaN  ...
# 18609                      NaN                NaN  NaN  ...
# 6171                  Swimming               male    M  ...
#
#                                         Species   \
# 1270                          Tiger shark, 2.3m
# 20564                                        NaN
# 8160                                         NaN
# 3477                                         NaN
# 22426                                        NaN
# 4566                                         NaN
# 4130   Tiger shark, 4.6 m to 7.6 m [15' to 25']
# 18339                                        NaN
# 18609                                        NaN
# 6171                                         NaN
#
#                                   Investigator or Source  \
# 1270                                      T. Peake, GSAF
# 20564                                                NaN
# 8160                                                 NaN
# 3477                             The Age, 4/11/1968, p.4
# 22426                                                NaN
# 4566   G.P. Whitley (1951), p.193; V.M. Coppleson (19...
# 4130                                        A. L. Tester
# 18339                                                NaN
# 18609                                                NaN
# 6171                                        Olaus Magnus
#
#                                  pdf  \
# 1270      2008.04.20.a-Adlington.pdf
# 20564                            NaN
# 8160                             NaN
# 3477       1968.04.11.R-Laiokeke.pdf
# 22426                            NaN
# 4566   1947.11.08.a-RupertElford.pdf
# 4130           1958.12.13-Weaver.pdf
# 18339                            NaN
# 18609                            NaN
# 6171   1555.00.00 - Olaus Magnus.pdf
#
#                                             href formula  \
# 1270   http://sharkattackfile.net/spreadsheets/pdf_di...
# 20564                                                NaN
# 8160                                                 NaN
# 3477   http://sharkattackfile.net/spreadsheets/pdf_di...
# 22426                                                NaN
# 4566   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4130   http://sharkattackfile.net/spreadsheets/pdf_di...
# 18339                                                NaN
# 18609                                                NaN
# 6171   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                     href Case Number.1  \
# 1270   http://sharkattackfile.net/spreadsheets/pdf_di...  2008.04.20.a
# 20564                                                NaN           NaN
# 8160                                                 NaN           NaN
# 3477   http://sharkattackfile.net/spreadsheets/pdf_di...  1968.04.11.R
# 22426                                                NaN           NaN
# 4566   http://sharkattackfile.net/spreadsheets/pdf_di...  1947.11.08.a
# 4130   http://sharkattackfile.net/spreadsheets/pdf_di...    1958.12.13
# 18339                                                NaN           NaN
# 18609                                                NaN           NaN
# 6171   http://sharkattackfile.net/spreadsheets/pdf_di...    1555.00.00
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 1270   2008.04.20.a         5033.0         NaN         NaN
# 20564           NaN            NaN         NaN         NaN
# 8160            NaN            NaN         NaN         NaN
# 3477   1968.04.11.R         2826.0         NaN         NaN
# 22426           NaN            NaN         NaN         NaN
# 4566   1947.11.08.a         1737.0         NaN         NaN
# 4130     1958.12.13         2173.0         NaN         NaN
# 18339           NaN            NaN         NaN         NaN
# 18609           NaN            NaN         NaN         NaN
# 6171     1555.00.00          132.0         NaN         NaN
#
# [10 rows x 24 columns]

# %%
#1 Para ordenar el DataFrame debemos ver qué columnas se repiten para eliminar: ej. Case number, Date, y case number 1 case number 2 se pueden dejar en una sola columna. 
#2 Left join o inner join para quedarnos solo con una info de estas columnas. #cambiar los nombres y estandarizar las columnas y sus valores. 
    #en Activity hay que hacer analisis para cambiarles el nombre a las actividsdes que sean las mismas pero con nombres similares.
#3 eliminar las filas que sean todas NaN en todas las columnas (el 75 % del archivo)
#4 eliminar los datos (filas) por fecha que sean irrelevantes, por ejemplo, la fila 6171 es el año 1555 y no me da ningun tipo de info, salvo la especie del tiburon y cómo ocurrió. 
#5 Eliminar las dos ultimas columnas porque no tienen valor. 
#6 la columna original order es el index. Podemos ordenarlo y ponerlo delante. 
#7 para la edad podemos coger la media para los valores que no tiene valor o no se encuentra el valor.

# %%
#datos importantes para sacar mis hipotesis: 
    #año vs. type of attack/activity
    #type of attack vs. region
    #gender + age vs. region 
#analizar la especie del tiburon y la region y el año
