# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
import chardet

# %%
import chardet

with open('attacks.csv', 'rb') as f:
    result = chardet.detect(f.read())
df = pd.read_csv('attacks.csv', encoding=result['encoding'])
print(df.head())
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %% [markdown]
# ### Total of entries 25 723 and only around 5 000 entries that are not null.

# %%
df.sample(20)
# Out:
#         Case Number         Date    Year        Type      Country  \
# 3206     1975.10.12  12-Oct-1975  1975.0  Unprovoked    AUSTRALIA
# 18063           NaN          NaN     NaN         NaN          NaN
# 13813           NaN          NaN     NaN         NaN          NaN
# 12164           NaN          NaN     NaN         NaN          NaN
# 24223           NaN          NaN     NaN         NaN          NaN
# 12455           NaN          NaN     NaN         NaN          NaN
# 16637           NaN          NaN     NaN         NaN          NaN
# 22988           NaN          NaN     NaN         NaN          NaN
# 1193     2008.11.06  06-Nov-2008  2008.0  Unprovoked  PHILIPPINES
# 12236           NaN          NaN     NaN         NaN          NaN
# 10664           NaN          NaN     NaN         NaN          NaN
# 1734   2003.10.05.c  05-Oct-2003  2003.0    Provoked          USA
# 12779           NaN          NaN     NaN         NaN          NaN
# ...

# %%
#To start with clean up: column names to list and then indexing 
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Case Number',
#  'Date',
#  'Year',
#  'Type',
#  'Country',
#  'Area',
#  'Location',
#  'Activity',
#  'Name',
#  'Sex ',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species ',
#  'Investigator or Source',
#  'pdf',
#  'href formula',
#  'href',
#  'Case Number.1',
#  'Case Number.2',
#  'original order',
#  'Unnamed: 22',
#  'Unnamed: 23']

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#lets standarize the name of the columns to work easier during cleanup and afterwards
df.columns= df.columns.str.lower()

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [case number, date, year, type, country, area, location, activity, name, sex , age, injury, fatal (y/n), time, species , investigator or source, pdf, href formula, href, case number.1, case number.2, original order, unnamed: 22, unnamed: 23]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [case_number, date, year, type, country, area, location, activity, name, sex_, age, injury, fatal_(y/n), time, species_, investigator_or_source, pdf, href_formula, href, case_number.1, case_number.2, original_order, unnamed:_22, unnamed:_23]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.columns.tolist()
# Out:
# ['case_number',
#  'date',
#  'year',
#  'type',
#  'country',
#  'area',
#  'location',
#  'activity',
#  'name',
#  'sex_',
#  'age',
#  'injury',
#  'fatal_(y/n)',
#  'time',
#  'species_',
#  'investigator_or_source',
#  'pdf',
#  'href_formula',
#  'href',
#  'case_number.1',
#  'case_number.2',
#  'original_order',
#  'unnamed:_22',
#  'unnamed:_23']

# %%
#Based on the non-null entried I will proceed to delete the columns that have the lesser columns to begin with and then we will create subsets to clean beased on our different hypothesis, so that we still have some data left in case something happens
df = df.drop(['case_number.1', 'case_number.2', 'unnamed:_22', 'unnamed:_23', 'time', 'href_formula', 'href', 'original_order'], axis=1, inplace=False)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [case_number, date, year, type, country, area, location, activity, name, sex_, age, injury, fatal_(y/n), species_, investigator_or_source, pdf]
# Index: []

# %%
df.head()
# Out:
#   case_number         date    year        type    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               injury fatal_(y/n)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             8702 non-null   object
#  1   date                    6302 non-null   object
#  2   year                    6300 non-null   float64
#  3   type                    6298 non-null   object
#  4   country                 6252 non-null   object
#  5   area                    5847 non-null   object
#  6   location                5762 non-null   object
#  7   activity                5758 non-null   object
#  8   name                    6092 non-null   object
#  9   sex_                    5737 non-null   object
#  10  age                     3471 non-null   object
#  11  injury                  6274 non-null   object
#  12  fatal_(y/n)             5763 non-null   object
#  13  species_                3464 non-null   object
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [case_number, date, year, type, country, area, location, activity, name, sex_, age, injury, fatal_(y/n), species_, investigator_or_source, pdf]
# Index: []

# %%
#As we can see in the printed info, case number has more no null vairants that date, and the information give is practically the same.
#We will delete the date column and change case number to datetime and proceed to rename the column to date

# %%
df1= df.copy()

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1= df1.drop(['date'], axis=1, inplace=False)

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.head(0)
# Out:
# Empty DataFrame
# Columns: [case_number, year, type, country, area, location, activity, name, sex_, age, injury, fatal_(y/n), species_, investigator_or_source, pdf]
# Index: []

# %%
df1['case_number']= pd.to_datetime(df1['case_number'], errors='coerce')

# %%
df1.head()
# Out:
#   case_number    year        type    country             area  \
# 0  2018-06-25  2018.0     Boating        USA       California
# 1  2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2  2018-06-09  2018.0     Invalid        USA           Hawaii
# 3  2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018-06-04  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               injury fatal_(y/n)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# ...

# %%
#I will create a copy of this "cleaner" subset to start cleaning furte¡hermore
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             3742 non-null   datetime64[ns]
#  1   year                    6300 non-null   float64
#  2   type                    6298 non-null   object
#  3   country                 6252 non-null   object
#  4   area                    5847 non-null   object
#  5   location                5762 non-null   object
#  6   activity                5758 non-null   object
#  7   name                    6092 non-null   object
#  8   sex_                    5737 non-null   object
#  9   age                     3471 non-null   object
#  10  injury                  6274 non-null   object
#  11  fatal_(y/n)             5763 non-null   object
#  12  species_                3464 non-null   object
#  13  investigator_or_source  6285 non-null   object
# ...

# %%
df2= df1.copy()

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
#Now we will clean the column 'sex_' as from previous analysis there were some unkown values
df2 = df2[df2['sex_'].isin(['F', 'M'])]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5731 entries, 0 to 6301
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             3448 non-null   datetime64[ns]
#  1   year                    5729 non-null   float64
#  2   type                    5727 non-null   object
#  3   country                 5686 non-null   object
#  4   area                    5339 non-null   object
#  5   location                5259 non-null   object
#  6   activity                5338 non-null   object
#  7   name                    5667 non-null   object
#  8   sex_                    5731 non-null   object
#  9   age                     3431 non-null   object
#  10  injury                  5717 non-null   object
#  11  fatal_(y/n)             5270 non-null   object
#  12  species_                3140 non-null   object
#  13  investigator_or_source  5716 non-null   object
# ...

# %%
df2 = df2.dropna()

# %%
df2 = df2.reset_index(drop=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1299 entries, 0 to 1298
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             1299 non-null   datetime64[ns]
#  1   year                    1299 non-null   float64
#  2   type                    1299 non-null   object
#  3   country                 1299 non-null   object
#  4   area                    1299 non-null   object
#  5   location                1299 non-null   object
#  6   activity                1299 non-null   object
#  7   name                    1299 non-null   object
#  8   sex_                    1299 non-null   object
#  9   age                     1299 non-null   object
#  10  injury                  1299 non-null   object
#  11  fatal_(y/n)             1299 non-null   object
#  12  species_                1299 non-null   object
#  13  investigator_or_source  1299 non-null   object
# ...

# %%
df2.sample()
# Out:
#     case_number    year        type    country               area  \
# 159  2013-10-28  2013.0  Unprovoked  AUSTRALIA  Western Australia
#
#           location    activity            name sex_ age  \
# 159  Turquoise Bay  Snorkeling  Glenda Simmons    F  60
#
#                        injury fatal_(y/n)                 species_  \
# 159  Lacerations to right arm           N  Blacktip reef shark, 1m
#
#     investigator_or_source                     pdf
# 159        AAP, 10/28/2013  2013.10.28-Simmons.pdf

# %%
df2.rename(columns={'sex_': 'sex'},inplace=True)

# %%
df2.rename(columns={'fatal_(y/n)':'fatal', 'species_': 'species', 'investigator_or_source': 'source'}, inplace=True)

# %%
df2.head(0)
# Out:
# Empty DataFrame
# Columns: [case_number, year, type, country, area, location, activity, name, sex, age, injury, fatal, species, source, pdf]
# Index: []

# %%
sns.countplot(x=df2["fatal"], hue=df2["sex"], palette="magma")
plt.ylabel("cases")
plt.legend(labels = ['female', 'male'])
plt.title("Fatality rate by sex", size=10);

# %%
df2 = df2[df2['fatal'].isin(['N', 'Y'])]

# %%
sns.countplot(x=df2["fatal"], hue=df2["sex"], palette="magma")
plt.ylabel("cases")
plt.legend(labels = ['female', 'male'])
plt.title("Fatality rate by sex", size=10);

# %%
unique_injury= df2['injury'].unique()
print(unique_injury)
# Out:
# ['No injury to occupant, outrigger canoe and paddle damaged'
#  'Minor injury to foot. PROVOKED INCIDENT'
#  'Minor bite to hand by captive shark. PROVOKED INCIDENT'
#  '5-inch cut to hand' 'No injury, shark bit hole in ski'
#  'Lacerations to right lower leg' 'Lacerations to left knee & lower leg'
#  'Injuries to right leg & hand' 'Minor injuries to legs'
#  ' The shark & man simply collided; neither were injured'
#  'Laceratons to right leg & foot'
#  'Puncture wounds to leff foot & lower leg'
#  'Lacerations to 4 toes of right foot' 'Injuries to right foot'
#  'No injury no attack. This is considerd an "encounter"'
#  'No injury, shark took his swimfin' 'Minor injury to left forearm'
#  'Severe lacerations to left thigh & knee'
#  'Minor injury to thigh, PROVOKED INCIDENT' 'Right leg bitten'
#  'Puncture wounds to left shoulder' 'FATAL' 'Minor injury to foot'
#  'Minor injuries' 'Lacerations to left hand' 'Abrasions'
#  'Lacerations to left foot' 'No injury, board bitten'
# ...

# %%
df2.drop(['injury'], axis=1, inplace=True)

# %%
df2.head()
# Out:
#   case_number    year        type       country                   area  \
# 0  2018-06-25  2018.0     Boating           USA             California
# 1  2018-05-27  2018.0  Unprovoked           USA                Florida
# 2  2018-05-24  2018.0    Provoked     AUSTRALIA             Queensland
# 3  2018-04-23  2018.0  Unprovoked      MALDIVES      Alifu Alifu Atoll
# 4  2018-04-22  2018.0  Unprovoked  SOUTH AFRICA  Western Cape Province
#
#                                             location        activity  \
# 0                        Oceanside, San Diego County        Paddling
# 1  Lighhouse Point Park, Ponce Inlet, Volusia County         Fishing
# 2                                    Cairns Aquarium  Feeding sharks
# 3                                          Madoogali         Fishing
# 4                     Robberg Beach, Plettenberg Bay   Paddle-skiing
#
#             name sex age fatal             species  \
# 0    Julie Wolfe   F  57     N         White shark
# ...

# %%
df2.drop(['source', 'pdf'], axis=1, inplace=True)
df2.head()
# Out:
#   case_number    year        type       country                   area  \
# 0  2018-06-25  2018.0     Boating           USA             California
# 1  2018-05-27  2018.0  Unprovoked           USA                Florida
# 2  2018-05-24  2018.0    Provoked     AUSTRALIA             Queensland
# 3  2018-04-23  2018.0  Unprovoked      MALDIVES      Alifu Alifu Atoll
# 4  2018-04-22  2018.0  Unprovoked  SOUTH AFRICA  Western Cape Province
#
#                                             location        activity  \
# 0                        Oceanside, San Diego County        Paddling
# 1  Lighhouse Point Park, Ponce Inlet, Volusia County         Fishing
# 2                                    Cairns Aquarium  Feeding sharks
# 3                                          Madoogali         Fishing
# 4                     Robberg Beach, Plettenberg Bay   Paddle-skiing
#
#             name sex age fatal             species
# 0    Julie Wolfe   F  57     N         White shark
# ...

# %%
unique_type= df2['type'].unique()
print(unique_type)
# Out:
# ['Boating' 'Unprovoked' 'Provoked' 'Invalid' 'Sea Disaster' 'Boat']

# %%
df2 = df2[df2['type'].isin(['Unprovoked', 'Provoked'])]

# %%
unique_type= df2['type'].unique()
print(unique_type)
# Out:
# ['Unprovoked' 'Provoked']

# %%
sns.countplot(x=df2["fatal"], hue=df2["type"], palette="Blues")
plt.ylabel("cases")
plt.legend(labels = ['Provoked', 'Unprovoked'])
plt.title("Fatality rate by sex", size=10);

# %%
df3=df.copy()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             8702 non-null   object
#  1   date                    6302 non-null   object
#  2   year                    6300 non-null   float64
#  3   type                    6298 non-null   object
#  4   country                 6252 non-null   object
#  5   area                    5847 non-null   object
#  6   location                5762 non-null   object
#  7   activity                5758 non-null   object
#  8   name                    6092 non-null   object
#  9   sex_                    5737 non-null   object
#  10  age                     3471 non-null   object
#  11  injury                  6274 non-null   object
#  12  fatal_(y/n)             5763 non-null   object
#  13  species_                3464 non-null   object
# ...

# %%
unique_country= df3['country'].unique()
print(unique_country)
# Out:
# ['USA' 'AUSTRALIA' 'MEXICO' 'BRAZIL' 'ENGLAND' 'SOUTH AFRICA' 'THAILAND'
#  'COSTA RICA' 'MALDIVES' 'BAHAMAS' 'NEW CALEDONIA' 'ECUADOR' 'MALAYSIA'
#  'LIBYA' nan 'CUBA' 'MAURITIUS' 'NEW ZEALAND' 'SPAIN' 'SAMOA'
#  'SOLOMON ISLANDS' 'JAPAN' 'EGYPT' 'ST HELENA, British overseas territory'
#  'COMOROS' 'REUNION' 'FRENCH POLYNESIA' 'UNITED KINGDOM'
#  'UNITED ARAB EMIRATES' 'PHILIPPINES' 'INDONESIA' 'CHINA' 'COLUMBIA'
#  'CAPE VERDE' 'Fiji' 'DOMINICAN REPUBLIC' 'CAYMAN ISLANDS' 'ARUBA'
#  'MOZAMBIQUE' 'FIJI' 'PUERTO RICO' 'ITALY' 'ATLANTIC OCEAN' 'GREECE'
#  'ST. MARTIN' 'FRANCE' 'PAPUA NEW GUINEA' 'TRINIDAD & TOBAGO' 'KIRIBATI'
#  'ISRAEL' 'DIEGO GARCIA' 'TAIWAN' 'JAMAICA' 'PALESTINIAN TERRITORIES'
#  'GUAM' 'SEYCHELLES' 'BELIZE' 'NIGERIA' 'TONGA' 'SCOTLAND' 'CANADA'
#  'CROATIA' 'SAUDI ARABIA' 'CHILE' 'ANTIGUA' 'KENYA' 'RUSSIA'
#  'TURKS & CAICOS' 'UNITED ARAB EMIRATES (UAE)' 'AZORES' 'SOUTH KOREA'
#  'MALTA' 'VIETNAM' 'MADAGASCAR' 'PANAMA' 'SOMALIA' 'NEVIS'
# ...

# %%
df3.head()
# Out:
#   case_number         date    year        type    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               injury fatal_(y/n)  \
# ...

# %%
df['case_number'] = pd.to_datetime(df['case_number'].str.strip(), format='%Y/%m/%d', errors='coerce')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             8702 non-null   object
#  1   date                    6302 non-null   object
#  2   year                    6300 non-null   float64
#  3   type                    6298 non-null   object
#  4   country                 6252 non-null   object
#  5   area                    5847 non-null   object
#  6   location                5762 non-null   object
#  7   activity                5758 non-null   object
#  8   name                    6092 non-null   object
#  9   sex_                    5737 non-null   object
#  10  age                     3471 non-null   object
#  11  injury                  6274 non-null   object
#  12  fatal_(y/n)             5763 non-null   object
#  13  species_                3464 non-null   object
# ...

# %%
df3.head()
# Out:
#   case_number         date    year        type    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               injury fatal_(y/n)  \
# ...

# %%
df3.drop(['date'], axis=1, inplace=True)

# %%
df3.head(0)
# Out:
# Empty DataFrame
# Columns: [case_number, year, type, country, area, location, activity, name, sex_, age, injury, fatal_(y/n), species_, investigator_or_source, pdf]
# Index: []

# %%
df3.rename(columns={'case_number':'date'}, inplace=True)

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    8702 non-null   object
#  1   year                    6300 non-null   float64
#  2   type                    6298 non-null   object
#  3   country                 6252 non-null   object
#  4   area                    5847 non-null   object
#  5   location                5762 non-null   object
#  6   activity                5758 non-null   object
#  7   name                    6092 non-null   object
#  8   sex_                    5737 non-null   object
#  9   age                     3471 non-null   object
#  10  injury                  6274 non-null   object
#  11  fatal_(y/n)             5763 non-null   object
#  12  species_                3464 non-null   object
#  13  investigator_or_source  6285 non-null   object
# ...

# %%
df3.rename(columns={'sex_':'sex', 'fatal_(y/n)':'fatal', 'species_': 'species'}, inplace=True)

# %%
df3.drop(['pdf', 'investigator_or_source', 'injury', 'name', 'location'],axis=1, inplace=True)

# %%
df3.head(0)
# Out:
# Empty DataFrame
# Columns: [date, year, type, country, area, activity, sex, age, fatal, species]
# Index: []

# %%
unique_species= df3['species'].unique()
print(unique_species)
# Out:
# ['White shark' nan '2 m shark' ... "12' tiger shark" 'Blue pointers'
#  'Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable']

# %%
df3 = df3[df3['type'].isin(['Unprovoked', 'Provoked'])]

# %%
unique_type_3= df3['type'].unique()
print(unique_type_3)
# Out:
# ['Unprovoked' 'Provoked']

# %%
count_type_3= df3['type'].value_counts()
print(count_type_3)
# Out:
# type
# Unprovoked    4595
# Provoked       574
# Name: count, dtype: int64

# %%
count_country_3= df3['country'].value_counts()
print(count_country_3)
# Out:
# country
# USA                     1929
# AUSTRALIA               1070
# SOUTH AFRICA             457
# PAPUA NEW GUINEA         123
# NEW ZEALAND              101
#                         ...
# GRAND CAYMAN               1
# MEXICO                     1
# NETHERLANDS ANTILLES       1
# EGYPT / ISRAEL             1
# CEYLON (SRI LANKA)         1
# Name: count, Length: 184, dtype: int64

# %%
most_shown_countries = count_country_3[count_country_3 > 50].index
df3= df3[df3['country'].isin(most_shown_countries)]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4062 entries, 1 to 6299
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      4061 non-null   object
#  1   year      4062 non-null   float64
#  2   type      4062 non-null   object
#  3   country   4062 non-null   object
#  4   area      3985 non-null   object
#  5   activity  3819 non-null   object
#  6   sex       3913 non-null   object
#  7   age       2666 non-null   object
#  8   fatal     4059 non-null   object
#  9   species   2232 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 349.1+ KB

# %%
count_country_3= df3['country'].value_counts()
print(count_country_3)
# Out:
# country
# USA                 1929
# AUSTRALIA           1070
# SOUTH AFRICA         457
# PAPUA NEW GUINEA     123
# NEW ZEALAND          101
# BAHAMAS               98
# BRAZIL                97
# MEXICO                72
# FIJI                  58
# REUNION               57
# Name: count, dtype: int64

# %%
sns.countplot(x=df3["country"], hue=df3["type"], palette="Blues")
plt.ylabel("cases")
plt.xticks(rotation=45)
plt.legend(labels = ['Unprovoked','Provoked'])
plt.title("Provokness by country", size=30);

# %%
plt.figure(figsize=(12, 6)) 
sns.countplot(x=df3['country'], hue=df3['type'], palette= 'Reds')
plt.ylabel('cases')
plt.xticks(rotation=45)
plt.legend(labels= ['Unprovoked', 'Provoked'])
plt.title("Provokness by country", size=25)
plt.show()

# %%
unique_activity_3= df3['activity'].unique()
print(unique_activity_3)
# Out:
# ['Standing' 'Surfing' 'Free diving' 'Kite surfing' 'Swimming' 'Fishing'
#  'Walking' 'Feeding sharks' 'Boogie boarding' 'Paddle-skiing'
#  'Body boarding' 'Stand-Up Paddleboarding' 'Wading' 'Scuba Diving'
#  'Kayak fishing for sharks' nan 'Diving' 'Snorkeling' 'Spearfishing'
#  'Surfing ' 'Kayaking / Fishing' 'Kayaking' 'Swimming, poaching abalone'
#  'Canoeing' 'SUP' 'Skimboarding' 'Touching a shark'
#  'Attempting to lasso a shark' 'Paddle boarding' 'Kakaying'
#  'Washing hands' 'Grabbing shark for a selfie' 'Surf skiing '
#  'Surf fishing' 'Floating' 'Surfng' 'SUP Foil boarding' 'Lobstering'
#  'Floating in tube' 'Teasing a shark' 'Surf-skiing' 'Body surfing'
#  'Windsurfing' 'Scuba diving' 'Lobster fishing' 'Swimming / Wading'
#  'Photographing fish' 'Kayak Fishing' 'Scallop diving on hookah'
#  'Body boarding ' 'Playing in the water' 'Body Boarding' 'Body surfing?'
#  'Playing' 'Attempting to rescue a shark' 'Photographing the shark'
# ...

# %%
count_activity_3= df3['activity'].value_counts()
print(count_activity_3)
# Out:
# activity
# Surfing                                                                                                    893
# Swimming                                                                                                   573
# Spearfishing                                                                                               238
# Fishing                                                                                                    217
# Wading                                                                                                     129
#                                                                                                           ...
# Free diving , but surfacing                                                                                  1
# During a shark fishing tournament, the 18' Boatem was capsized by waves, throwing 3 men into the water       1
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4062 entries, 1 to 6299
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      4061 non-null   object
#  1   year      4062 non-null   float64
#  2   type      4062 non-null   object
#  3   country   4062 non-null   object
#  4   area      3985 non-null   object
#  5   activity  3819 non-null   object
#  6   sex       3913 non-null   object
#  7   age       2666 non-null   object
#  8   fatal     4059 non-null   object
#  9   species   2232 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 349.1+ KB

# %%
most_activities_3 = count_activity_3[count_activity_3 > 19].index
df3= df3[df3['activity'].isin(most_activities_3)]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2653 entries, 1 to 6299
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      2652 non-null   object
#  1   year      2653 non-null   float64
#  2   type      2653 non-null   object
#  3   country   2653 non-null   object
#  4   area      2610 non-null   object
#  5   activity  2653 non-null   object
#  6   sex       2588 non-null   object
#  7   age       1879 non-null   object
#  8   fatal     2651 non-null   object
#  9   species   1468 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 228.0+ KB

# %%
count_activity_3= df3['activity'].value_counts()
print(count_activity_3)
# Out:
# activity
# Surfing            893
# Swimming           573
# Spearfishing       238
# Fishing            217
# Wading             129
# Bathing            101
# Standing            85
# Diving              66
# Snorkeling          63
# Body boarding       61
# Scuba diving        48
# Body surfing        44
# Swimming            32
# Treading water      28
# Pearl diving        28
# Boogie boarding     25
# Free diving         22
# Name: count, dtype: int64

# %%
df3['activity']= df3['activity'].replace({'Swimming': 'Swimming',
                                          'Bathing': 'Swimming',
                                          'Free diving': 'Diving',
                                          'Scuba diving': 'Diving',
                                          'Pearl diving': 'Diving',
                                          'Snorkeling': 'Diving',
                                          'Body boarding': 'Surfing',
                                          'Boogie boarding': 'Diving',
                                          'Spread fishing': 'Fishing',
                                          'Standing': 'Wading',
                                          'Treading water': 'Swimming',
                                          'Body surfing': 'Surfing',
                                          })

# %%
count_activity_3= df3['activity'].value_counts()
print(count_activity_3)
# Out:
# activity
# Surfing         998
# Swimming        702
# Diving          252
# Spearfishing    238
# Fishing         217
# Wading          214
# Swimming         32
# Name: count, dtype: int64

# %%
df3['activity'] = df3['activity'].str.strip()
print(df3['activity'].value_counts())
# Out:
# activity
# Surfing         998
# Swimming        734
# Diving          252
# Spearfishing    238
# Fishing         217
# Wading          214
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5)) 
sns.countplot(x=df3['activity'], hue=df3['fatal'], palette= 'Pastel2')
plt.ylabel('cases')
plt.legend(labels= ['NON FATAL', 'FATAL'])
plt.title("Fatality by activity", size=25)
plt.show()

# %%
plt.figure(figsize=(12, 6)) 
sns.countplot(x=df3['country'], hue=df3['fatal'], palette= 'Pastel1')
plt.ylabel('cases')
plt.xticks(rotation=45)
plt.legend(labels= ['NON FATAL', 'FATAL'])
plt.title("Fatality by country", size=25)
plt.show()

# %%
heatmap_data = pd.crosstab(index=[df3['country'], df3['activity']], columns=df3['fatal'])
plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", linewidths=0.5)
plt.title('Fatality by actibity in each country Heatmap')
plt.show()

# %%
count_fatal_3= df3['fatal'].value_counts()
print(count_fatal_3)
# Out:
# fatal
# N          2204
# Y           430
# UNKNOWN      16
#  N            1
# Name: count, dtype: int64

# %%
df3['fatal'] = df3['fatal'].str.strip()
print(df3['fatal'].value_counts())
# Out:
# fatal
# N          2205
# Y           430
# UNKNOWN      16
# Name: count, dtype: int64

# %%
df3 = df3[df3['fatal'].isin(['N', 'Y'])]
print(df3['fatal'].value_counts())
# Out:
# fatal
# N    2205
# Y     430
# Name: count, dtype: int64

# %%
heatmap_data = pd.crosstab(index=[df3['country'], df3['activity']], columns=df3['fatal'])
plt.figure(figsize=(10, 9))
sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", linewidths=0.15)
plt.title('Fatality by actibity in each country Heatmap')
plt.show()

# %%
#lets analyze only the fatalities as this much of information feels confusing

df_fatlities= df3[df3['fatal']== 'Y']

# %%
df_fatlities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 430 entries, 6 to 6299
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      430 non-null    object
#  1   year      430 non-null    float64
#  2   type      430 non-null    object
#  3   country   430 non-null    object
#  4   area      419 non-null    object
#  5   activity  430 non-null    object
#  6   sex       416 non-null    object
#  7   age       269 non-null    object
#  8   fatal     430 non-null    object
#  9   species   165 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 37.0+ KB

# %%
count_fatal_fatal= df_fatlities['fatal'].value_counts()
print(count_fatal_fatal)
# Out:
# fatal
# Y    430
# Name: count, dtype: int64

# %%
heatmap_data = pd.crosstab(index=[df_fatlities['country'], df_fatlities['activity']], columns=df_fatlities['fatal'])
plt.figure(figsize=(10, 9))
sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", linewidths=0.15)
plt.title('Fatality by actibity in each country Heatmap')
plt.show()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2635 entries, 1 to 6299
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      2634 non-null   object
#  1   year      2635 non-null   float64
#  2   type      2635 non-null   object
#  3   country   2635 non-null   object
#  4   area      2592 non-null   object
#  5   activity  2635 non-null   object
#  6   sex       2573 non-null   object
#  7   age       1873 non-null   object
#  8   fatal     2635 non-null   object
#  9   species   1463 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 226.4+ KB

# %%
df3.sample(10)
# Out:
#               date    year        type       country                   area  \
# 2765    1987.10.11  1987.0  Unprovoked  SOUTH AFRICA  Western Cape Province
# 1653  2004.07.27.a  2004.0  Unprovoked           USA                  Texas
# 5136    1927.01.03  1927.0  Unprovoked     AUSTRALIA        New South Wales
# 2995    1982.01.29  1982.0  Unprovoked  SOUTH AFRICA  Eastern Cape Province
# 409     2015.06.23  2015.0  Unprovoked           USA         South Carolina
# 95    2017.09.02.a  2017.0  Unprovoked           USA                Florida
# 2343    1995.09.13  1995.0  Unprovoked           USA                Florida
# 2893    1984.06.15  1984.0  Unprovoked  SOUTH AFRICA  Western Cape Province
# 5521    1903.05.04  1903.0  Unprovoked        MEXICO               Veracruz
# 2029    2000.07.22  2000.0  Unprovoked           USA                Florida
#
#           activity sex  age fatal                               species
# ...

# %%
dates_df3= df3['date'].value_counts()
print(dates_df3)
# Out:
# date
# 1980.07.00      2
# 2014.08.02      2
# 2012.09.02.b    2
# 2013.10.05      2
# 2006.09.02      2
#                ..
# 2005.08.06      1
# 2005.07.27      1
# 2005.07.23      1
# 2005.07.15      1
# ND.0003         1
# Name: count, Length: 2628, dtype: int64

# %%
df3['date'] = df3['date'].str.replace(r'[a-zA-Z]$', '', regex=True)

# %%
dates_df3= df3['date'].value_counts()
print(dates_df3)
# Out:
# date
# 1952.00.00.    4
# 2001.04.12.    4
# 2012.06.14.    4
# 1995.07.28.    4
# 2017.04.29.    4
#               ..
# 2004.05.22.    1
# 2004.05.28     1
# 2004.05.23.    1
# 2004.05.29     1
# ND.0003        1
# Name: count, Length: 2389, dtype: int64

# %%
df3['date'] = df3['date'].str.replace(r'[.]$', '', regex=True)

# %%
dates_df3= df3['date'].value_counts()
print(dates_df3)
# Out:
# date
# 1995.07.28    4
# 2017.04.29    4
# 2001.04.12    4
# 1952.00.00    4
# 2012.06.14    4
#              ..
# 2004.03.31    1
# 2004.04.05    1
# 2004.04.07    1
# 2004.04.26    1
# ND.0003       1
# Name: count, Length: 2382, dtype: int64

# %%
df3['date'] = pd.to_datetime(df3['date'], format='%Y.%m.%d', errors='coerce')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2635 entries, 1 to 6299
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      2451 non-null   datetime64[ns]
#  1   year      2635 non-null   float64
#  2   type      2635 non-null   object
#  3   country   2635 non-null   object
#  4   area      2592 non-null   object
#  5   activity  2635 non-null   object
#  6   sex       2573 non-null   object
#  7   age       1873 non-null   object
#  8   fatal     2635 non-null   object
#  9   species   1463 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 226.4+ KB

# %%
df3['date'].value_counts()
# Out:
# date
# 2012-06-14    4
# 2017-04-29    4
# 2001-04-12    4
# 1995-07-28    4
# 2003-10-31    3
#              ..
# 2005-04-13    1
# 2005-04-25    1
# 2005-05-02    1
# 2005-05-15    1
# 1751-07-27    1
# Name: count, Length: 2229, dtype: int64

# %%
df3.hist(['date'])
# Out:
# array([[<Axes: title={'center': 'date'}>]], dtype=object)

# %%
df3['year'].value_counts()
# Out:
# year
# 2014.0    77
# 2016.0    75
# 2012.0    75
# 2015.0    74
# 2013.0    73
#           ..
# 1884.0     1
# 1864.0     1
# 1865.0     1
# 1866.0     1
# 1908.0     1
# Name: count, Length: 182, dtype: int64

# %%
df3= df3[(df3['date']>= '1960-01-01')]

# %%
df3.hist(['date'])
# Out:
# array([[<Axes: title={'center': 'date'}>]], dtype=object)

# %%
sns.scatterplot(x='date', y='country', hue='fatal', data=df3);
plt.show()

# %%
df_usa= df3.copy()

# %%
usa= 'USA'
df_usa= df_usa[df_usa['country']== usa]
print(df_usa)
# Out:
#            date    year        type country            area  activity sex age  \
# 1    2018-06-18  2018.0  Unprovoked     USA         Georgia    Wading   F  11
# 7    2018-05-27  2018.0  Unprovoked     USA         Florida   Fishing   M  52
# 9    2018-05-26  2018.0  Unprovoked     USA         Florida    Wading   M  12
# 11   2018-05-21  2018.0  Unprovoked     USA  South Carolina    Diving   M  10
# 12   2018-05-13  2018.0  Unprovoked     USA  South Carolina  Swimming   M  10
# ...         ...     ...         ...     ...             ...       ...  ..  ..
# 3969 1960-08-24  1960.0  Unprovoked     USA     Connecticut    Diving   M  38
# 3985 1960-06-24  1960.0  Unprovoked     USA         Florida    Diving   M  39
# 3988 1960-06-04  1960.0  Unprovoked     USA         Georgia  Swimming   M  24
# 3991 1960-05-19  1960.0  Unprovoked     USA      California  Swimming   F  16
# 4007 1960-03-31  1960.0  Unprovoked     USA         Florida  Swimming   M  42
#
# ...

# %%
df_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1047 entries, 1 to 4007
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      1047 non-null   datetime64[ns]
#  1   year      1047 non-null   float64
#  2   type      1047 non-null   object
#  3   country   1047 non-null   object
#  4   area      1047 non-null   object
#  5   activity  1047 non-null   object
#  6   sex       1029 non-null   object
#  7   age       905 non-null    object
#  8   fatal     1047 non-null   object
#  9   species   614 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 90.0+ KB

# %%
df_usa.hist(['date'])
# Out:
# array([[<Axes: title={'center': 'date'}>]], dtype=object)

# %%
df_usa['fatal'].value_counts()
# Out:
# fatal
# N    1021
# Y      26
# Name: count, dtype: int64
